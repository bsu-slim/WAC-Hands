# %% [markdown]
# ### This notebook gets the hand data csv file and rewrites the tendon values to align with the theory of mirror neurons. Using ridge regression, a mapping is created between visual features and tendon values. These new tendon values created from the visual features are written in a new file called hand_data_mirror

# %%
import pandas as pd
from sklearn.metrics import *
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from collections import defaultdict as dd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from slir import SparseLinearRegression

import operator
import re
from collections import Counter

#from textblob import TextBlob
#from textblob import Word

from IPython.display import HTML, display
from IPython.display import Image

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib  

import pickle
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ### Read data, remove punctuation, stem, and tokenize the descriptions, and add  camera one-hot encoding

# %%
def read_raw_data():
    data = pd.read_csv('../data/hand_data3_separated.csv',  index_col=False)

    # remove punctuation
    data['desc_list'] = data.description.apply(lambda x: [i for i in re.sub(r'[^\w\s]','',str(x)).lower().split()])
    data['desc_str'] = data.desc_list.apply(lambda x: ' '.join(x))

    #add one-hot encoding
    camera_data = pd.get_dummies(data.camera_angle)
    data = pd.concat([data, camera_data], axis=1)
    cols = data.columns.tolist()
    cols = cols[:8] + cols[-4:] + cols[8:-4]
    data = data[cols]
    
    #get words and vocabs
    words = [y for x in data.desc_list for y in x]
    vocab = list(set(words))
    print('number of unique words in our data:', len(vocab), '\nnumber of word tokens in our data: ', len(words))
    
    return data, words, vocab

    #OLD CODE
    # stemming seems to make things worse
    #import nltk
    #import nltk.stem.snowball as stem
    #wnl = stem.EnglishStemmer()
    #Select only the straight_on camera angles (lowers accuracy, so don't do it)
    #data = data.loc[data['camera_angle'] == 'straight_on']
    #Fix spelling mistakes (textblob doesn't work well for this)
    #for phrase in data.description:
    #    blob = TextBlob(phrase)
    #    print(blob.correct())

# %% [markdown]
# ### split off some of the data for test/eval/held out (this should only be done the first time)

# %% [raw]
# data.index
#
# train_data, test_data = train_test_split(data, test_size=0.2)
# test_data, heldout_data = train_test_split(test_data, test_size=0.5)
#
# train_data.to_pickle("../data/train_data_visual.pkl")
# test_data.to_pickle("../data/test_data_visual.pkl")
# heldout_data.to_pickle("../data/heldout_data_visual.pkl")
#
# train_data.shape, test_data.shape, heldout_data.shape

# %% [markdown]
# ### Read in data, stack it, and clean it

# %%
def read_in_data():
    train_data = pd.read_pickle("../data/train_data3_separated.pkl")
    test_data = pd.read_pickle("../data/test_data3_separated.pkl")
    return train_data, test_data

def stack_training_data(mydata):
    s = mydata.apply(lambda x: pd.Series(x['desc_list']),axis=1).stack().reset_index(level=1, drop=True)
    s.name = 'word'
    mydata = mydata.join(s)
    return mydata

def remove_unwated_words(mydata, vocab, words):
    wanted_words = list(set(words))
    #unwanted_words = {'hand', 'and', 'the', 'a', 'with', 'is', 'are', 'to', 'of', 'finger', 'fingers', 'thumb'}
    unwanted_words = {'hand', 'and', 'the', 'a', 'with', 'is', 'are', 'to', 'of'}
    unwanted_tags = {}
    for curr_word in vocab:
        #w = Word(word)
        #final = w.lemmatize("v")
        #blob = TextBlob(curr_word)
        ##tags = blob.tags
        #if tags[0][1] in unwanted_tags:
        #    wanted_words.remove(curr_word)
        if curr_word in unwanted_words:
            wanted_words.remove(curr_word)
    mydata = mydata.loc[mydata['word'].isin(wanted_words)]
    return mydata

# %%
_, words, vocab = read_raw_data()
train_data, test_data = read_in_data()
train_data[:10]
# Out:
# number of unique words in our data: 1109
# number of word tokens in our data:  13617
#       poseID camera_angle                              description   T1   T2  \
# 710      177         left    thumb and finger next to pinky curled  0.7  0.0
# 1083      27       behind         hand facing away slightly curled  0.0  0.3
# 1224      63  straight_on                                   c's up  0.0  0.7
# 485      121        above                                     curl  0.3  0.3
# 348       87  straight_on            Open hand; ring finger curled  0.3  0.0
# 898      224         left                                OK symbol  0.7  0.7
# 1336      91  straight_on     middle; little fingers slightly bent  0.3  0.0
# 463      115       behind                  looks like bird ostrich  0.3  0.3
# 1017      11        above                    pointing at something  0.0  0.0
# 1188      54  straight_on  grasping but your  index finger is bent  0.0  0.7
#
#        T3   T4   T5  above  behind                   ...                    \
# 710   0.3  0.7  0.0      0       0                   ...
# 1083  0.0  0.0  0.0      0       1                   ...
# 1224  0.3  0.0  0.0      0       0                   ...
# 485   0.3  0.3  0.3      1       0                   ...
# 348   0.0  0.7  0.0      0       0                   ...
# 898   0.0  0.7  0.7      0       0                   ...
# 1336  0.3  0.0  0.3      0       0                   ...
# 463   0.0  0.7  0.3      0       1                   ...
# 1017  0.3  0.0  0.7      1       0                   ...
# 1188  0.0  0.0  0.0      0       0                   ...
#
#           f993          f994          f995      f996      f997          f998  \
# 710   0.000011  3.930000e-05  7.770000e-06  0.000008  0.000024  1.870000e-06
# 1083  0.000003  4.670000e-05  9.240000e-06  0.000002  0.000019  5.690000e-07
# 1224  0.000005  5.280000e-06  1.130000e-06  0.000004  0.000014  7.940000e-07
# 485   0.000020  7.180000e-06  1.220000e-05  0.000001  0.000017  3.440000e-06
# 348   0.000009  5.530000e-05  1.240000e-06  0.000004  0.000017  2.220000e-06
# 898   0.000014  6.050000e-06  2.210000e-06  0.000002  0.000006  1.580000e-06
# 1336  0.000012  3.320000e-05  3.050000e-06  0.000006  0.000017  1.470000e-06
# 463   0.000005  9.530000e-05  1.460000e-05  0.000005  0.000043  9.310000e-07
# 1017  0.000051  4.160000e-07  7.180000e-06  0.000001  0.000005  3.580000e-06
# 1188  0.000005  7.670000e-06  9.700000e-07  0.000005  0.000014  7.840000e-07
#
#           f999     f1000                                       desc_list  \
# 710   0.000050  0.000819   [thumb, and, finger, next, to, pinky, curled]
# 1083  0.000027  0.000051          [hand, facing, away, slightly, curled]
# 1224  0.000009  0.000387                                        [cs, up]
# 485   0.000075  0.000024                                          [curl]
# 348   0.000019  0.000167              [open, hand, ring, finger, curled]
# 898   0.000027  0.000087                                    [ok, symbol]
# 1336  0.000010  0.000253       [middle, little, fingers, slightly, bent]
# 463   0.000028  0.000276                    [looks, like, bird, ostrich]
# 1017  0.000174  0.000012                       [pointing, at, something]
# 1188  0.000009  0.000400  [grasping, but, your, index, finger, is, bent]
#
#                                     desc_str
# 710    thumb and finger next to pinky curled
# 1083        hand facing away slightly curled
# 1224                                   cs up
# 485                                     curl
# 348             open hand ring finger curled
# 898                                ok symbol
# 1336     middle little fingers slightly bent
# 463                  looks like bird ostrich
# 1017                   pointing at something
# 1188  grasping but your index finger is bent
#
# [10 rows x 1014 columns]

# %%
data, words, vocab = read_raw_data()

data.columns[:15]
# Out:
# number of unique words in our data: 1109
# number of word tokens in our data:  13617
# Index(['poseID', 'camera_angle', 'description', 'T1', 'T2', 'T3', 'T4', 'T5',
#        'above', 'behind', 'left', 'straight_on', 'f1', 'f2', 'f3'],
#       dtype='object')

# %%
START_COL = 'T1' 
END_COL = 'T5'
V_START_COL = 'above'
V_END_COL = 'f1000'

y = train_data.ix[:,START_COL:END_COL].as_matrix()
X = train_data.ix[:,V_START_COL:V_END_COL].as_matrix()
y_test = test_data.ix[:,START_COL:END_COL].as_matrix()
X_test = test_data.ix[:,V_START_COL:V_END_COL].as_matrix()
y_all = data.ix[:,START_COL:END_COL].as_matrix()
X_all = data.ix[:,V_START_COL:V_END_COL].as_matrix()

print("train", X.shape, y.shape)
print("test", X_test.shape, y_test.shape)
print("all", X_all.shape, y_all.shape)
# Out:
# train (1555, 1004) (1555, 5)
# test (194, 1004) (194, 5)
# all (1944, 1004) (1944, 5)

# %%
from sklearn.linear_model import *
import numpy as np

model = Ridge(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=None, normalize=True, 
              random_state=False, solver='auto', tol=0.01)
model.fit(X, y)
# Out:
# Ridge(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=True, random_state=False, solver='auto', tol=0.01)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
import math

y_actual = y_test
y_predicted = model.predict(X_test) 

rms = sqrt(mean_squared_error(y_actual, y_predicted))
print(rms)
print(y_actual[:10])
print(np.around(y_predicted[:10], decimals=1))
# Out:
# 0.07578534546014949
# [[0.  0.3 0.7 0.7 0. ]
#  [0.  0.7 0.  0.7 0.7]
#  [0.7 0.7 0.7 0.7 0. ]
#  [0.7 0.7 0.7 0.7 0.7]
#  [0.7 0.7 0.7 0.7 0.7]
#  [0.  0.3 0.7 0.3 0.3]
#  [0.3 0.3 0.3 0.3 0.7]
#  [0.3 0.  0.  0.7 0.7]
#  [0.7 0.3 0.7 0.3 0.7]
#  [0.7 0.  0.3 0.7 0.3]]
# [[-0.   0.2  0.7  0.7 -0. ]
#  [-0.   0.7 -0.   0.7  0.7]
#  [ 0.7  0.7  0.7  0.7  0. ]
#  [ 0.7  0.7  0.7  0.7  0.7]
#  [ 0.7  0.7  0.7  0.7  0.7]
#  [ 0.   0.3  0.7  0.3  0.3]
#  [ 0.3  0.3  0.3  0.3  0.7]
#  [ 0.3  0.   0.   0.6  0.7]
#  [ 0.7  0.3  0.8  0.3  0.8]
#  [ 0.7 -0.   0.3  0.7  0.3]]

# %% [markdown]
# ## Produce mirror .pkl

# %%
new_tendons = model.predict(X_all) 
new_tendons.shape # this should match above
# Out:
# (1944, 5)

# %%
# new_tendons now needs to replace the columns from START_COL to END_COL
data_old = pd.read_csv('../data/hand_data3_separated.csv',  index_col=False)

# %%
#modify the data
data_new = data_old
columns = ["T1", "T2", "T3", "T4", "T5"]
for i, col in enumerate(columns):    
    print(i, col)
    data_new = data_new.drop([col], axis=1)
    data_new.insert(loc=i+3, column=col, value=new_tendons[:,i],)
    
data_new
# Out:
# 0 T1
# 1 T2
# 2 T3
# 3 T4
# 4 T5
#       poseID camera_angle                                        description  \
# 0          0  straight_on  front of left hand with all fingers standing u...
# 1          0        above                                           pointing
# 2          0         left                                  side veiw of hand
# 3          0       behind        hand away all fingers slightly bent inwards
# 4          1  straight_on  hand raised; palm facing self; pinky slightly ...
# 5          1        above         about to grab someone on the shoulder hand
# 6          1         left         fingers slightly curved; palm facing right
# 7          1       behind                                       back of hand
# 8          2  straight_on         One finger is down while all others are up
# 9          2        above                    All fingers are bend except one
# 10         2         left                    Raising hand to ask a question.
# 11         2       behind  hand facing away with all fingers slightly ben...
# 12         3  straight_on  hand facing toward all fingers straight except...
# 13         3        above                                          dino hand
# 14         3         left                                            relaxed
# 15         3       behind  The hand appears to be scrolling on a tablet s...
# 16         4  straight_on                                            Gangrel
# 17         4        above                                     showing a size
# 18         4         left                     hailing a cab with two fingers
# 19         4       behind            In this pose fingers are shown in order
# 20         5  straight_on  counting 3 hand with closed ring and pinky finger
# 21         5        above  palm face down like holding a computer mouse; ...
# 22         5         left                 waving to a person across the room
# 23         5       behind               hand extended reaching for something
# 24         6  straight_on                                 making a gang sign
# 25         6        above  Fingers bent down varying degrees with some fi...
# 26         6         left                                STYLISH FINGER POSE
# 27         6       behind                                        dorsal hand
# 28         7  straight_on  palm facing toward; thumb out; fingers bent sl...
# 29         7        above                          waving with two fingers;;
# ...      ...          ...                                                ...
# 1914     235         left  Side view of blue-green hand; thump-side-up ma...
# 1915     235       behind  All fingers are bent with the middle finger to...
# 1916     236  straight_on  Vertical hand; pam facing front; with thub; fi...
# 1917     236        above  back view of fingers towards you looks like th...
# 1918     236         left  The index finger is bent and resting on the thumb
# 1919     236       behind                          back facing reaching hand
# 1920     237  straight_on                                            Respect
# 1921     237        above             hand palm down with thumb tucked under
# 1922     237         left  Hand with fingers curled down and thumb touchi...
# 1923     237       behind                                        make a fist
# 1924     238  straight_on  Palm facing hand. All fingers partially closed...
# 1925     238        above                                Grip bicycle handle
# 1926     238         left                                Clenched fist a bit
# 1927     238       behind                                               fist
# 1928     239  straight_on        middle finger on top of thumb; fingers bent
# 1929     239        above                       a hand playing an instrument
# 1930     239         left           Hand is posed as though grasping a pole.
# 1931     239       behind           All the fingers are bent to close a fist
# 1932     240  straight_on        Hand is closed with pinky sticking outward.
# 1933     240        above                                              Money
